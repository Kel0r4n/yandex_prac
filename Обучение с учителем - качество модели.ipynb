# %% [markdown]
# # Проект:обучение с учителем: качество модели

# %% [markdown]
# # Описание проекта
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# #### Цель: разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность

# %% [markdown]
# #### Подход к решению:
# Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# Нужно собрать данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# #### Исходные данные
# Файл market_file_csv содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении:
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение - последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# Файл market_money_csv это таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период
#
# Файл market_time_csv - таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.
#
# Файл money.csv это таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли.

# %% [markdown]
# #### План действий:
# Часть 1. Изучить общую информацию
# - Загрузить данные и изучить их
#
# Часть 2. Провести предобработку
# - Устранить пропуски, если таковые имеются
# - Проверить соответствие типов данных
# - Устанить аномалии
# - Избавиться от дубликатов
#
# Часть 3. Провести исследовательский анализ
#
# Часть 4. Объединение датафреймов
#
# Часть 5. Провести корреляционный анализ
#
# Часть 6. Обучить моделей с помощью пайплайнов
# - Подобрать гиперпараметры
# - Обучить 4 модели
# - Выбрать подходящую метрику
# - Выбрать лучшую модель
# Часть 7. Провести анализ важности признаков с помощью SHAP
#
# Часть 8. Сегментировать покупателей и сформулировать предложения по работе с сегментом для увеличения покупательской активности.
#
# Часть 9. Итоговый вывод

# %% [markdown]
# ## Импорты

# %%
# !pip install scikit-learn -U
# Out:
# ...
#      |████████████████████████████████| 13.4 MB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 301 kB 101.9 MB/s eta 0:00:01
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...

# %%
# !pip install phik -q

# %%
# !pip install shap -q

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import shap
import math 
from phik import phik_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import Pipeline
from phik.report import plot_correlation_matrix
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer 
from sklearn.preprocessing import (OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler)
from sklearn.metrics import (f1_score, roc_auc_score, accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay)

# %% [markdown]
# ## Загрузка данных

# %%
df_market_file = pd.read_csv('/datasets/market_file.csv', sep=',', decimal='.')
df_market_money = pd.read_csv('/datasets/market_money.csv', sep=',', decimal='.')
df_market_time = pd.read_csv('/datasets/market_time.csv', sep=',', decimal='.')
df_money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# %%
display(df_market_file.head())
display(df_market_money.head())
display(df_market_time.head())
df_money.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
display(df_market_file.info())
display(df_market_money.info())
display(df_market_time.info())
df_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
display(df_market_file.describe())
display(df_market_money.describe())
display(df_market_time.describe())
df_money.head()
# Out:
#                   id  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# ...

# %% [markdown]
# # Вывод:
# Видим, что в таблицах нет пропущенных значений, названия столбцов стоит привести к змеиному стилю, а также на первый взгляд видно ошибку в df_maket_time, в столбце Период написано предыдцщий_месяц, а должно быть предыдущий_месяц, также видим ошибку в df_market_file, тк там написано стандартт, вместо стандарт, со всем этим будем бороться на этапе предобработки.
# С типами данных все в порядке, возможно стоит поменять тип в столбце "разрешить сообщать" таблицы df_market_file с object на bool

# %% [markdown]
# ## Предобработка

# %%
#Приведем все столбцы к змеиному стилю
datas = [df_market_file,df_market_money,df_market_time,df_money]
for data in datas:
    data.columns = [x.lower() for x in data.columns]
    data.columns = [x.replace(' ', '_') for x in data.columns]

# %%
df_market_file #выводим, чтобы посмотреть как изменились наши колонки (не стал выводить все дф, тк изменяли циклом)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась   стандартт                нет
# 3     215351                 Снизилась   стандартт                 да
# 4     215352                 Снизилась   стандартт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
for c in df_market_file[df_market_file.select_dtypes(exclude='number').columns]: #при помощи цикла найдем дубликаты в данных
    print(f'уникальные значения столбца "{c}"')
    print(f'{df_market_file[c].value_counts()}:/n')
    print()
# Out:
# уникальные значения столбца "покупательская_активность"
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64:/n
#
# уникальные значения столбца "тип_сервиса"
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64:/n
#
# уникальные значения столбца "разрешить_сообщать"
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64:/n
#
# уникальные значения столбца "популярная_категория"
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64:/n

# %% [markdown]
# Видим, что в столбце тип сервиса есть дубилкат "стандартт", его необходимо исправить

# %%
df_market_file['тип_сервиса'] = df_market_file['тип_сервиса'].str.replace('стандартт', 'стандарт') 
df_market_time['период'] = df_market_time['период'].str.replace('предыдцщий_месяц', 'предыдущий_месяц')#исправляем неявный дубликат

# %%
for c in df_market_time[df_market_time.select_dtypes(exclude='number').columns]:
    print(f'уникальные значения столбца "{c}"')
    print(f'{df_market_time[c].value_counts()}:/n')
    print()
# Out:
# уникальные значения столбца "период"
# предыдущий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64:/n

# %%
df_market_time.columns
# Out:
# Index(['id', 'период', 'минут'], dtype='object')

# %% [markdown]
# Ошибка в слове предыдущий, в целом то она ничего не меняет, но исправим

# %%
for c in df_market_money[df_market_money.select_dtypes(exclude='number').columns]: #при помощи цикла найдем дубликаты в market_money
    print(f'уникальные значения столбца "{c}"')
    print(f'{df_market_money[c].value_counts()}:/n')
    print()
# Out:
# уникальные значения столбца "период"
# предыдущий_месяц       1300
# текущий_месяц          1300
# препредыдущий_месяц    1300
# Name: период, dtype: int64:/n

# %% [markdown]
# Тут все в порядке, а в таблице df_money нет словесных значений, а значит и неявных дубликатов мы там не найдем

# %% [markdown]
# # Вывод
# Еще на этапе загрузки и первичного изучения данных мы выявили, что пропусков в данных нет
# Дубликаты были устранены в df_market_file
# В остальных данных дубликатов не обнаржуено
# Все названия столбцовы приведены к змеиному стилю

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# Рассмотрим как распределяются значения в наших данных

# %%
def cat_plots(df,about): #функция для построения графиков по категориальным признакам, с аргументами:
    #df - табл с данными, about - название графика 
    df.value_counts().plot(  
        kind = 'barh', 
        color = 'crimson')
    plt.xlabel('Частота'),
    plt.ylabel("Значения"),
    plt.title('Распределение значений по признаку {0}'.format(about));
    plt.show()

# %%
def num_plots(df,about):#функция для построения графиков по количественным признакам признакам
    fig,axes = plt.subplots(1, 2,figsize = (15,5))
    plt.subplot(1,2,1)
    a = df.count()
    b = round(1 + 3.322*math.log(a)) #для определения оптимального количества интервалов используется правило Стёрджеса
    plt.hist(df,bins = b,ec='black')
    plt.xlabel('Значения')
    plt.ylabel("Частота")
    plt.title('Распределение значений по признаку {0}'.format(about)),
    plt.subplot(1,2,2)
    plt.boxplot(df, vert=False)
    plt.title('Ящик с усами для признака {0}'.format(about))
    plt.show();

# %% [markdown]
# # Рассмотрим распределение числовых и категориальных признаков в таблице df_market_file

# %%
for_num = df_market_file[df_market_file.select_dtypes(include='number').columns].drop(['id'], axis=1)

for x in for_num:
    num_plots(for_num[x],x)
    plt.show()

# %%
for c in df_market_file[df_market_file.select_dtypes(exclude='number').columns]:
    cat_plots(df_market_file[c],c)

# %% [markdown]
# # Вывод по df_market_file
# По числовым признакам:
#
# - маркет_актив_6 мес: распределение похоже на нормальное с пиком в 4
# - маркет_актив_тек_мес: 3 пика - 3.0, 4.0, 5.0
# - длительность: в целом, все пользователи зарегестрировались в разное время, самый новый пользователь примерно 100 дней назад, самый старый около 1100
# - акционные покупки: в среднем пользователи покупают 25% товаров со скидкой, также есть часть пользователей, которые за последние пол года покупали товары почти всегда только лишь на акциях (доля близка к 1)
# - средний_просмотр_категорий_за_визит: в среднем пользователи смотрят около 2-3 категорий за визит
# - неоплаченные_продукты_штук_квартал: в основном у пользователей в корзине лежит от 1 до 4 неоплаченных товаров
# - ошибка_сервиса: нормальное распределение, в среднем пользователи "ловят" 4 ошибки за время посещения сайта
# - страниц_за_визит: в среднем пользователи смотрят от 4 до 11 страниц за один визит за 3 мес
#
# По категориальным признакам:
#
# - Преимущественно, покупательская активность пользователей остается неизменной, а у примерно 40% покупателей она снижается
# - Большинство пользователей пользуются сервисом стандарт
# - Большинство покупателей хотят получать дополнительные предложения о товаре
# - Наиболее попуряной категорий считаются товары для детей, а наименее популряной - кухонная посуда

# %% [markdown]
# # Рассмотрим распределение числовых и категориальных признаков в таблице df_market_time

# %%
for x in df_market_time[df_market_time.select_dtypes(include='number').columns].drop(['id'],axis=1):
    num_plots(df_market_time[x],x)

# %%
for c in df_market_time[df_market_time.select_dtypes(exclude='number').columns]:
    cat_plots(df_market_time[c],c)

# %% [markdown]
# # Вывод
# Числовые признаки
#
# - Пользователи проводят на сайте от 8 до 15 минут, в основном около 13
#
# Категориальные признаки
#
# - Пользователи пользуются сайтом каждый месяц одинаково

# %% [markdown]
# # Рассмотрим распределение числовых и категориальных признаков в таблице df_market_money

# %%
for x in df_market_money[df_market_money.select_dtypes(include='number').columns].drop(['id'],axis=1):
    num_plots(df_market_money[x],x)

# %% [markdown]
# График неинформативен, потому что еще в начале мы заметили, что у данного столбцa есть выбросы, максимальное значение - более 100 000, а минимальное 0.

# %%
df_market_money_hist = (df_market_money.query('0 < выручка < 100000')
                       [df_market_money.select_dtypes(include='number').columns]
                       .drop(['id'], axis=1))
num_plots(df_market_money_hist,'Выручка')

# %%
for c in df_market_money[df_market_money.select_dtypes(exclude='number').columns]:
    cat_plots(df_market_money[c],c)

# %% [markdown]
# # Вывод
# По числовым признакам
#
# - Нормальное распределение, большинство наблюдений находятся в промежутке 4500-5500, в оснвоном вырукчка составлять 5000
#
# По категориальным признакам
#
# - Выручка зафикисрована во всех предложенных месяцах поровну

# %% [markdown]
# # Рассмотрим распределение числовых и категориальных признаков в таблице df_money

# %%
for x in df_money[df_money.select_dtypes(include='number').columns].drop(['id'],axis=1):
    num_plots(df_money[x],x)

# %% [markdown]
# # Вывод
# - Нормальное распределение, наиболее часто встречающееся значение прибыли - 4

# %% [markdown]
# # Отберем клиентов с покупательской активностью не менее трёх месяцев

# %%
non_active = df_market_money.loc[df_market_money['выручка']==0]['id'] #таблица с неактивными пользователям
non_active.unique() #выводим неактивынх пользователей
# Out:
# array([215348, 215357, 215359])

# %%
active_users_df = df_market_money[df_market_money['id'].isin(non_active) == False] #Отибраем активных пользователей
active_users_df['id'].nunique()
# Out:
# 1297

# %%
df_market_money.loc[df_market_money['выручка']>100000]['id'] #находим строку с выручку больше 100000
# Out:
# 98    215380
# Name: id, dtype: int64

# %%
active_users_df = active_users_df.query('id != 215380') #удаляем эту строку

# %%
active_users_df['id'].nunique()
# Out:
# 1296

# %%
df_market_money = active_users_df

# %% [markdown]
# # Вывод по результатам исследовательского анализа
# - Почти везде данные распределены нормально
#
# В df market
# - маркет_актив_6 мес: распределение похоже на нормальное с пиком в 4
# - маркет_актив_тек_мес: Мультимодальное распределение, 3 пика - 3.0, 4.0, 5.0
# - длительность: Нормальное распределение или стремящееся к нему, в целом, все пользователи зарегестрировались в разное время, самый новый пользователь примерно 100 дней назад, самый старый около 1100
# - акционные покупки: Бимодальное распределение, в среднем пользователи покупают 25% товаров со скидкой, также есть часть пользователей, которые за последние пол года покупали товары почти всегда только лишь на акциях (доля близка к 1)
# - средний_просмотр_категорий_за_визит: Нормальное распределение, в среднем пользователи смотрят около 2-3 категорий за визит
# - неоплаченные_продукты_штук_квартал: Нормальное, смещенное влево распределение, в основном у пользователей в корзине лежит от 1 до 4 неоплаченных товаров
# - ошибка_сервиса: нормальное распределение, в среднем пользователи "ловят" 4 ошибки за время посещения сайта
# - страниц_за_визит: Нормальное, смещенное влево распрделение, в среднем пользователи смотрят от 4 до 11 страниц за один визит за 3 мес
# - Преимущественно, покупательская активность пользователей остается неизменной, а у примерно 40% покупателей она снижается
# - Большинство пользователей пользуются сервисом стандарт
# - Большинство покупателей хотят получать дополнительные предложения о товаре
# - Наиболее попуряной категорий считаются товары для детей, а наименее популряной - кухонная посуда
#
# В df time
# - Нормальное распределение, Пользователи проводят на сайте от 8 до 15 минут, в основном около 13
# - Пользователи пользуются сайтом каждый месяц одинаково
#
# В df money
#
# - Нормальное распределение, наиболее часто встречающееся значение прибыли - 4

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# Учитывая, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделаем отдельный столбец для каждого периода

# %%
df1 = (df_market_money.query('период == "текущий_месяц"').drop(['период'], axis=1).rename(columns={'выручка': 'выручка_в_текущем_месяце'}))

df2 = (df_market_money.query('период == "предыдущий_месяц"').drop(['период'], axis=1).rename(columns={'выручка': 'выручка_в_предыдущем_месяце'}))

df3 = (df_market_money.query('период == "препредыдущий_месяц"').drop(['период'], axis=1).rename(columns={'выручка': 'выручка_в_препредыдущем_месяце'}))

df4 = (df_market_time.query('период == "текущий_месяц"').drop(['период'], axis=1).rename(columns={'минут': 'минут_в_текущем_месяце'}))

df5 = (df_market_time.query('период == "предыдущий_месяц"').drop(['период'], axis=1).rename(columns={'минут': 'минут_в_предыдущем_месяце'}))
#создали отдельные стобцы для каждого преиода

# %%
df = (df_market_file
      .merge(df1,on='id')
      .merge(df2,on='id')
      .merge(df3,on='id')
      .merge(df4,on='id')
      .merge(df5,on='id')).reset_index(drop=True) #объединяем все в один дф

# %%
print(df.shape)
df.head() #проверяем как объединились наши данные
# Out:
# (1296, 18)
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# # Вывод по объединению таблиц
# Объединили датафреймы в один, при этом сделав для каждого периода отдельный столбец

# %% [markdown]
# ## Корреляционный анализ

# %%
phik_overview = (
    df
    .drop('id', axis=1)
    .phik_matrix(verbose=False))

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'Корреляция $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# Целевой - покупательская активность
# Входные - все, кроме длительности и маркет_актив_тек_мес

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Из графиков исследовательского анализа видно, что соотношение классов в целевом признаке непропорционально, поэтому воспользуемся стратификацией

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# выделяем в отдельные переменные целевой признак и входные признаки
X = df.drop(columns=['покупательская_активность', 'id','длительность','маркет_актив_тек_мес',])
y = df['покупательская_активность']

# разбиваем данные на выборки с учётом стратификации по целевому признаку
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    random_state=RANDOM_STATE, 
    test_size=TEST_SIZE, 
    stratify=y
)

# %%
from sklearn.preprocessing import LabelEncoder #преобразовываем целевой признак в бинарный 1/0
le = LabelEncoder()
y_train_le=le.fit_transform(y_train) 
le.classes_
y_test_le=le.transform(y_test)

# %%
# создаём списки с названиями признаков для кодирования и масштабирования/стандартизации
# признаки для кодирования OHE
ohe_columns = ['популярная_категория']

# признаки для кодирования OrdinalEncoder
ord_columns = ['разрешить_сообщать','тип_сервиса']

# Количественные признаки для скалера
num_columns = ['маркет_актив_6_мес', 
               'акционные_покупки', 
               'средний_просмотр_категорий_за_визит', 
               'неоплаченные_продукты_штук_квартал', 
               'ошибка_сервиса', 
               'страниц_за_визит', 
               'выручка_в_текущем_месяце', 
               'выручка_в_предыдущем_месяце', 
               'выручка_в_препредыдущем_месяце', 
               'минут_в_текущем_месяце', 
               'минут_в_предыдущем_месяце']

# добавляем OHE кодирование 
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))])

# добавляем Ordinal кодирование 
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ord', OrdinalEncoder(
    categories=[
        ['да','нет'],
        ['стандарт','премиум']
    ], 
    handle_unknown='use_encoded_value', 
    unknown_value=np.nan)),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 6),
        'models__max_features': range(2, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True,class_weight='balanced')],
        'models__kernel': ['rbf','sigmoid', 'linear', 'poly'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    n_iter=5,
    random_state=RANDOM_STATE,
    n_jobs=-1
)
# обучаем лучшую модель на тренировочных данных
randomized_search.fit(X_train, y_train_le)

# выводим на экран параметры лучшей модели и метрику ROC-AUC на тренировочной выборке
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print(f'Параметры лучшей модели:\n{randomized_search.best_params_}')
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

# проверяем работу модели на тестовой выборке
y_test_pred = randomized_search.predict_proba(X_test)
y_tp_one=y_test_pred[:,1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test_le, y_tp_one)}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %% [markdown]
# Мною была выбрана метрика roc_auc, тк в нашем случае имеет место быть несбалансированный целевой признак,а также потому что мы решаем задачу бинарной классификации, в этом случае данная метрика является наиболее эффктивной и объективной

# %%
result = pd.DataFrame(randomized_search.cv_results_)
display(result[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score'))
# Out:
#    rank_test_score                                       param_models  \
# 3                1  SVC(class_weight='balanced', probability=True,...
# 2                2                             KNeighborsClassifier()
# 0                3            DecisionTreeClassifier(random_state=42)
# 1                4            DecisionTreeClassifier(random_state=42)
# 4                5            DecisionTreeClassifier(random_state=42)
#
#    mean_test_score                                             params
# 3         0.895840  {'preprocessor__num': MinMaxScaler(), 'models_...
# 2         0.856245  {'preprocessor__num': MinMaxScaler(), 'models_...
# 0         0.825076  {'preprocessor__num': MinMaxScaler(), 'models_...
# 1         0.810552  {'preprocessor__num': MinMaxScaler(), 'models_...
# 4         0.679641  {'preprocessor__num': StandardScaler(), 'model...

# %% [markdown]
# # Вывод:
# Построили пайплайн и выбрали лучшую модель и гиперпараметры к ней, выбор моделей стоял среди:
# - DecisionTreeClassifier()
# - KNeighborsClassifier()
# - LogisticRegression()
# - SVC()
#
# Наилучшей же моделью озказалась модель SVC, со скайлером : MinMaxScaler, и ядром linear

# %% [markdown]
# ## Анализ важности признаков

# %%
#Обучим нашу лучшую модель
# кодируем категориальные признаки с помощью OneHotEncoder()
encoder = OneHotEncoder(drop='first',sparse_output=False)
X_train_ohe = encoder.fit_transform(X_train[ohe_columns])
X_test_ohe = encoder.transform(X_test[ohe_columns])
ohe_encoder_col_names = encoder.get_feature_names_out()

# %%
# кодируем категориальные признаки с помощью OrdinalEncoder()
ord_encoder = OrdinalEncoder()
X_train_ord = ord_encoder.fit_transform(X_train[ord_columns])
X_test_ord = ord_encoder.transform(X_test[ord_columns])

# %%
# масштабируем количественные признаки с помощью MinMaxScaler()
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train[num_columns])
X_test_scaled = scaler.transform(X_test[num_columns])

# %%
X_train_ohe = pd.DataFrame(X_train_ohe, columns=ohe_encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=ohe_encoder_col_names)

X_train_ord = pd.DataFrame(X_train_ord, columns=ord_columns)
X_test_ord = pd.DataFrame(X_test_ord, columns=ord_columns)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_columns)

# %%
# объединяем все в датафреймы
first = pd.concat([X_train_ohe, X_train_ord], axis=1)
X_model_train = pd.concat([first, X_train_scaled], axis=1)

second = pd.concat([X_test_ohe, X_test_ord], axis=1)
X_model_test = pd.concat([second, X_test_scaled], axis=1)

# %%
# обучаем модель
model = SVC(kernel='linear', class_weight='balanced',probability=True, random_state=42)
model.fit(X_model_train, y_train_le)
X_pred = model.predict(X_model_train)
y_pred = model.predict(X_model_test)

probas_train = model.predict_proba(X_model_train)[:,1]
probas_test = model.predict_proba(X_model_test)[:,1]

# считаем метрику ROC-AUC для тренировочных и тестовых данных
roc_auc_cv = cross_val_score(model, X_model_train, y_train_le, scoring='roc_auc').mean()
print(f'ROC-AUC на тренировочной выборке: {round(roc_auc_cv, 3)}')
print(f'ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test_le, y_pred), 3)}')

# оценка качества модели по метрике accuracy
model_acc = accuracy_score(y_test_le, y_pred)
print('Accuracy:', round(model_acc, 3))
# Out:
# ROC-AUC на тренировочной выборке: 0.896
# ROC-AUC на тестовой выборке: 0.878
# Accuracy: 0.892

# %%
explainer = shap.LinearExplainer(model, X_model_test)
shap_values = explainer(X_model_test)
shap.summary_plot(shap_values)

# %%
selector = SelectKBest(f_classif, k=14)
selector.fit(X_model_train, y_train_le)

features_names = X_model_train.columns[selector.get_support(indices=True)]
    

X_train_new = X_model_train[list(features_names)]
X_test_new = X_model_test[list(features_names)]

model = SVC(kernel = 'linear', class_weight='balanced',random_state=RANDOM_STATE,probability=True)
model.fit(X_train_new, y_train_le)

acc_new = accuracy_score(y_test_le, model.predict(X_test_new))

coefs = model.coef_[0]
feature_importance = pd.DataFrame({'Признак': features_names, 'Значимость': np.abs(coefs)})
feature_importance = feature_importance.sort_values(by='Значимость', ascending=True)
feature_importance.plot(x='Признак', 
                        y='Значимость', 
                        kind='barh', 
                        figsize=(15,5))
plt.title('Значимость признаков')
plt.show();

# %% [markdown]
# # Вывод

# %% [markdown]
# Исходя из графика, наиболее важные признаки:
#
# - страниц за визит
# - минут в предыдущем месяце
# - акционные покупки
# - минут в текущем месяце
# - неоплаченные продукты штук квартал
# - маркет актив 6 месяцев
#
# Практически не влияют на целевой:
#
# - признак разрешить сообщать
# - признак тип сервиса
# - а также популярная категория
#
#
# Высокие значения признаков страниц за визит и минут в предыдуем_месяце увеличивают вероятность принадлежности наблюдений к классу 0(покупательская активность не изменилась), т.е, если пользователь смотрит много страниц за визит, активно пользуется интернет магазином, то скорее всего его покупательская активность снижаться не будет
#
# Низкие значения акционные покупки и неоплаченные покупкуи штук квартал увеличивают вероятность принадлежности наблюдений к классу 1 (покупателькая активность снизилась), т.е. у пользователей, с низкой долей акционных покупок, снижаласть покупательская активность
#
# При моделировании и принятии бизнес-решений стоит учесть,что:
#
# Веротяность того, что покупаетель совершит покупку на сайте, его покупательская активность повыситься, сильно растет от того,есть ли на сайте акционные предложения, то есть стоит проводить больше акций.
#
# Также стоит учесть, что чем дольше пользователь проведет на сайте времени, как в текущем месяце, так и в прошлом, тем больше вероятность того, что его покупательская активность не упадет

# %% [markdown]
# ## Сегментация покупателей

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# добавялем столбцы с прогнозами
train['predicts'] = probas_train.tolist()
train['прогноз'] = X_pred.tolist()
test['predicts'] = probas_test.tolist()
test['прогноз'] = y_pred.tolist()


# объединяем и добавялем столбец 'id'
final_df = pd.concat([train, test])
final_df = pd.merge(df['id'], final_df, left_index=True, right_index=True)


# переименовываем для удобства столбец 'класс_прогноз'
final_df = final_df.rename(columns={'класс_прогноз': 'прогноз_покуп_актив'})

# добавялем данные о прибыльности
final_df = final_df.merge(df_money, on='id')

final_df['прогноз'] = le.inverse_transform(final_df['прогноз'])
final_df
# Out:
#           id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 0     215349     премиум                 да                 4.4
# 1     215350    стандарт                нет                 4.9
# 2     215351    стандарт                 да                 3.2
# 3     215352    стандарт                нет                 5.1
# 4     215353    стандарт                 да                 3.3
# ...      ...         ...                ...                 ...
# 1291  216643    стандарт                 да                 6.6
# 1292  216644    стандарт                нет                 5.1
# 1293  216645    стандарт                 да                 4.1
# 1294  216646    стандарт                 да                 6.3
# 1295  216647     премиум                 да                 4.0
#
#       акционные_покупки            популярная_категория  \
# 0                  0.75                Товары для детей
# 1                  0.14               Домашний текстиль
# ...

# %%
def probability(x):
    if x> 0.7:
        return 'высокая вероятность снижения'
    else:
        return 'низкая вероятность снижения'

# %%
final_df['вероятность_снижения']=final_df['predicts'].apply(probability)

# %%
#теперь выведем сегмент пользователей с прибылью выше 5 и высокой веротяностью того, что покупательская способность снизится
segment = final_df.query('прибыль > 5 & вероятность_снижения == "высокая вероятность снижения"')

# %%
print(f'Количество пользователей нашего сегмента: {len(segment)}')
segment
# Out:
# Количество пользователей нашего сегмента: 54
#           id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 17    215368     премиум                 да                 3.8
# 36    215388    стандарт                 да                 3.5
# 39    215391     премиум                 да                 3.5
# 44    215396    стандарт                 да                 3.4
# 48    215400    стандарт                нет                 4.4
# 49    215401     премиум                 да                 3.4
# 61    215413     премиум                 да                 4.0
# 73    215425    стандарт                 да                 4.1
# 87    215439     премиум                нет                 3.4
# 97    215449     премиум                 да                 2.4
# 104   215456    стандарт                 да                 1.7
# 107   215459     премиум                 да                 4.1
# 132   215484     премиум                нет                 2.9
# ...

# %% [markdown]
# Для анализа возьмем подгруппу покупаетелей с долей акционных покупок более 0.8 и сравним их со всеми остальными клиентами

# %%
#Покупатели, которые совершают покупки в основном на скидках
print('Количество покупателей с долей акционных покупок выше 0.8:', 
      segment[segment['акционные_покупки'] > 0.8]['id'].count())


print('Разрешают ли они отправлять себе сообщения:')
print(segment[segment['акционные_покупки'] > 0.8]['разрешить_сообщать'].value_counts())
print()

print('Самые популярные категории:')
print(segment[segment['акционные_покупки'] > 0.8]['популярная_категория'].value_counts())
print()
print('Типы сервиса')
print(segment[segment['акционные_покупки'] > 0.8]['тип_сервиса'].value_counts())
print()

(segment[segment['акционные_покупки'] > 0.8]['популярная_категория']
 .value_counts(ascending=True)
 .plot(kind='barh', color='r', ec='black', lw=1, alpha=0.65, width=0.7))
plt.title('Самые популярные категории', size=15)
plt.show()
# Out:
# Количество покупателей с долей акционных покупок выше 0.8: 16
# Разрешают ли они отправлять себе сообщения:
# да     11
# нет     5
# Name: разрешить_сообщать, dtype: int64
#
# Самые популярные категории:
# Товары для детей                        4
# Кухонная посуда                         4
# Домашний текстиль                       3
# Техника для красоты и здоровья          2
# Косметика и аксесуары                   2
# Мелкая бытовая техника и электроника    1
# Name: популярная_категория, dtype: int64
#
# Типы сервиса
# стандарт    13
# премиум      3
# Name: тип_сервиса, dtype: int64

# %%
z=(segment[segment['акционные_покупки'] > 0.8]['разрешить_сообщать']
 .value_counts(ascending=True))
x=(segment[segment['акционные_покупки'] < 0.8]['разрешить_сообщать']
 .value_counts(ascending=True))

ax = z.plot(kind='barh',
    ec='black',
    lw=1,
    label='raw',
    figsize=(10,7),
    alpha=1,
    facecolor='blue')

exe = x.plot(
    kind='barh',
    ax=ax,
    ec='black',
    lw=0.5,
    alpha=0.5,
    facecolor='black')
plt.grid()
plt.title('Влияние рассылки на снижение покупательской активности', size=15)
plt.xlabel('Значимость', size=12)
plt.ylabel('Разрешают ли пользователи отправлять себе сообщения', size=12)
plt.legend(['Низкая вероятность',
            'Высокая вероятность'], prop={'size': 13}, title='Снижение покупательской активности')
plt.show()

# %%
v=(segment[segment['акционные_покупки'] > 0.8]['тип_сервиса']
 .value_counts(ascending=True))
x=(segment[segment['акционные_покупки'] < 0.8]['тип_сервиса']
 .value_counts(ascending=True))

ax = v.plot(kind='barh',
    ec='black',
    lw=1,
    label='raw',
    figsize=(10,7),
    alpha=1,
    facecolor='blue')

exe = x.plot(
    kind='barh',
    ax=ax,
    ec='black',
    lw=0.5,
    alpha=0.5,
    facecolor='black')
plt.grid()
plt.title('Влияние типа сервиса на вероятность снижения покупательской активности', size=15)
plt.xlabel('Значимость', size=12)
plt.ylabel('Тип сервиса', size=12)
plt.legend(['Низкая вероятность',
            'Высокая вероятность'], prop={'size': 13}, title='Снижение покупательской активности')
plt.show()

# %% [markdown]
# Вывод:
#
# Думаю, что для того, чтобы повысить этому сегменту покупательскую активность, стоит предложить пользователям промокоды на скидку в самых популрярных категориях, также каким-либо образом способствовать их более продолжительному нахождению на сайте.
# Предлогать им больше товаров, для того, чтобы повысить количество просмотренных категорий за визит.
#
# Также предлагаю сделать пользователям со стандартным уровнем сервиса скидку на покупку премиальной подписки, тк как мы видим, низкая вероятность снижения покупательской активности как раз у пользователей с премиумом

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В результате проделанной работы:
#
# - Мы провели предобработку данных и выявили, что в данных нет пропусков, типы данных корректны, а имеющиеся неявные дубликаты были исправлены
#
# Также был проведен исследовательский анализ в ходе которого было вяснено, что:
# - Почти везде данные распределены нормально
#
# В df market
# - маркет_актив_6 мес: распределение похоже на нормальное с пиком в 4
# - маркет_актив_тек_мес: 3 пика - 3.0, 4.0, 5.0
# - длительность: в целом, все пользователи зарегестрировались в разное время, самый новый пользователь примерно 100 дней назад, самый старый около 1100
# - акционные покупки: в среднем пользователи покупают 25% товаров со скидкой, также есть часть пользователей, которые за последние пол года покупали товары почти всегда только лишь на акциях (доля близка к 1)
# - средний_просмотр_категорий_за_визит: в среднем пользователи смотрят около 2-3 категорий за визит
# - неоплаченные_продукты_штук_квартал: в основном у пользователей в корзине лежит от 1 до 4 неоплаченных товаров
# - ошибка_сервиса: нормальное распределение, в среднем пользователи "ловят" 4 ошибки за время посещения сайта
# - страниц_за_визит: в среднем пользователи смотрят от 4 до 11 страниц за один визит за 3 мес
# - Преимущественно, покупательская активность пользователей остается неизменной, а у примерно 40% покупателей она снижается
# - Большинство пользователей пользуются сервисом стандарт
# - Большинство покупателей хотят получать дополнительные предложения о товаре
# - Наиболее попуряной категорий считаются товары для детей, а наименее популряной - кухонная посуда
#
# В df time
# - Пользователи проводят на сайте от 8 до 15 минут, в основном около 13
# - Пользователи пользуются сайтом каждый месяц одинаково
#
# В df money
#
# - наиболее часто встречающееся значение прибыли - 4
#
# Также был проведен корреляционный анализ и объединение датафреймов
#
# для выбора лучшей комбинации модели и гиперпараметров был создан пайплайн, в который вошли модели:
#
# - DecisionTreeClassifier()
# - KNeighborsClassifier()
# - LogisticRegression()
# - SVC()
#
# Для всех моделей были подобраны гиперпараметры.
#
# Эффективность выбранной модели оценивали метрикой ROC-AUC. Данная метрика лучше всего подходит для задачи бинарной классификации с несбалансированным целевым признаком.
#
# В результате была выбрана лучшая модель:
#
# SVC(kernel='linear')
# и скалером MinMaxScaler()
#
# Метрика ROC-AUC лучшей модели на тренировочной выборке: 0.893
#
# Метрика ROC-AUC лучшей модели на тестовой выборке: 0.875
#
# Выбранный сегмент для анализа:
#
# - покупатели с высокой прибыльностью (>5)
# - сниженная покупательской активностью
#
# Предложения для выбранного сегмента покупателей:
#
# - Предложить пользователям промокоды на скидку в самых популрярных категориях
# - Способствовать их более продолжительному нахождению на сайте.
# - Предлагать им больше товаров, для того, чтобы повысить количество просмотренных категорий за визит.
# - Сделать пользователям со стандартным уровнем сервиса скидку на покупку премиальной подписки
